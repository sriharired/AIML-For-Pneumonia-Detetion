# %% [markdown]
# # CS470/CS670 Team 6 Final Project: Proposal for Pneumonia Detection Using Chest X-Ray Images

# %%
# Import required libraries
import os
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import warnings
from tensorflow.keras.applications import MobileNetV2,ResNet50

# Suppress warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Load Dataset

# %%
# Download dataset using kagglehub
import kagglehub
dataset_path = kagglehub.dataset_download("paultimothymooney/chest-xray-pneumonia")

print(f"Dataset downloaded to: {dataset_path}")

# Print directory structure
for root, dirs, files in os.walk(dataset_path):
    print(f"Directory: {root}")
    print(f"Subdirectories: {dirs}")
    print(f"Files: {files}")
    print("-" * 40)
# Out:
# Dataset downloaded to: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2
# Subdirectories: ['chest_xray']
# Files: []
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray
# Subdirectories: ['test', '__MACOSX', 'chest_xray', 'val', 'train']
# Files: []
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/test
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: []
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/test/NORMAL
# Subdirectories: []
# Files: ['NORMAL2-IM-0251-0001.jpeg', 'NORMAL2-IM-0286-0001.jpeg', 'NORMAL2-IM-0343-0001.jpeg', 'IM-0016-0001.jpeg', 'NORMAL2-IM-0326-0001.jpeg', 'NORMAL2-IM-0219-0001.jpeg', 'NORMAL2-IM-0195-0001.jpeg', 'NORMAL2-IM-0206-0001.jpeg', 'IM-0025-0001.jpeg', 'NORMAL2-IM-0105-0001.jpeg', 'NORMAL2-IM-0096-0001.jpeg', 'NORMAL2-IM-0110-0001.jpeg', 'NORMAL2-IM-0058-0001.jpeg', 'NORMAL2-IM-0374-0001-0001.jpeg', 'NORMAL2-IM-0337-0001.jpeg', 'IM-0061-0001.jpeg', 'NORMAL2-IM-0079-0001.jpeg', 'IM-0069-0001.jpeg', 'IM-0022-0001.jpeg', 'IM-0019-0001.jpeg', 'NORMAL2-IM-0317-0001.jpeg', 'IM-0011-0001-0001.jpeg', 'IM-0097-0001.jpeg', 'NORMAL2-IM-0073-0001.jpeg', 'NORMAL2-IM-0290-0001.jpeg', 'IM-0029-0001.jpeg', 'NORMAL2-IM-0381-0001.jpeg', 'IM-0093-0001.jpeg', 'NORMAL2-IM-0196-0001.jpeg', 'NORMAL2-IM-0350-0001.jpeg', 'NORMAL2-IM-0302-0001.jpeg', 'IM-0033-0001-0002.jpeg', 'IM-0087-0001.jpeg', 'NORMAL2-IM-0305-0001.jpeg', 'NORMAL2-IM-0362-0001.jpeg', 'IM-0110-0001.jpeg', 'IM-0027-0001.jpeg', 'NORMAL2-IM-0338-0001.jpeg', 'IM-0037-0001.jpeg', 'NORMAL2-IM-0132-0001.jpeg', 'NORMAL2-IM-0129-0001.jpeg', 'NORMAL2-IM-0041-0001.jpeg', 'NORMAL2-IM-0321-0001.jpeg', 'NORMAL2-IM-0271-0001.jpeg', 'NORMAL2-IM-0359-0001.jpeg', 'NORMAL2-IM-0028-0001.jpeg', 'NORMAL2-IM-0033-0001.jpeg', 'NORMAL2-IM-0346-0001.jpeg', 'IM-0103-0001.jpeg', 'IM-0007-0001.jpeg', 'NORMAL2-IM-0029-0001.jpeg', 'NORMAL2-IM-0364-0001.jpeg', 'NORMAL2-IM-0198-0001.jpeg', 'IM-0111-0001.jpeg', 'IM-0095-0001.jpeg', 'NORMAL2-IM-0282-0001.jpeg', 'NORMAL2-IM-0051-0001.jpeg', 'NORMAL2-IM-0345-0001.jpeg', 'NORMAL2-IM-0307-0001.jpeg', 'NORMAL2-IM-0111-0001.jpeg', 'NORMAL2-IM-0238-0001.jpeg', 'IM-0017-0001.jpeg', 'NORMAL2-IM-0325-0001.jpeg', 'IM-0050-0001.jpeg', 'NORMAL2-IM-0213-0001.jpeg', 'NORMAL2-IM-0120-0001.jpeg', 'NORMAL2-IM-0233-0001.jpeg', 'NORMAL2-IM-0007-0001.jpeg', 'NORMAL2-IM-0366-0001.jpeg', 'NORMAL2-IM-0330-0001.jpeg', 'NORMAL2-IM-0130-0001.jpeg', 'NORMAL2-IM-0066-0001.jpeg', 'NORMAL2-IM-0210-0001.jpeg', 'NORMAL2-IM-0311-0001.jpeg', 'IM-0105-0001.jpeg', 'NORMAL2-IM-0278-0001.jpeg', 'NORMAL2-IM-0322-0001.jpeg', 'NORMAL2-IM-0013-0001.jpeg', 'NORMAL2-IM-0267-0001.jpeg', 'NORMAL2-IM-0313-0001.jpeg', 'NORMAL2-IM-0376-0001.jpeg', 'IM-0036-0001.jpeg', 'NORMAL2-IM-0232-0001.jpeg', 'NORMAL2-IM-0329-0001.jpeg', 'NORMAL2-IM-0339-0001.jpeg', 'NORMAL2-IM-0327-0001.jpeg', 'IM-0091-0001.jpeg', 'NORMAL2-IM-0207-0001.jpeg', 'NORMAL2-IM-0275-0001.jpeg', 'NORMAL2-IM-0274-0001.jpeg', 'NORMAL2-IM-0333-0001.jpeg', 'IM-0045-0001.jpeg', 'IM-0063-0001.jpeg', 'NORMAL2-IM-0292-0001.jpeg', 'NORMAL2-IM-0341-0001.jpeg', 'IM-0009-0001.jpeg', 'NORMAL2-IM-0315-0001.jpeg', 'NORMAL2-IM-0280-0001.jpeg', 'NORMAL2-IM-0222-0001.jpeg', 'NORMAL2-IM-0287-0001.jpeg', 'NORMAL2-IM-0201-0001.jpeg', 'IM-0101-0001.jpeg', 'NORMAL2-IM-0380-0001.jpeg', 'NORMAL2-IM-0123-0001.jpeg', 'IM-0086-0001.jpeg', 'NORMAL2-IM-0352-0001.jpeg', 'NORMAL2-IM-0368-0001.jpeg', 'IM-0013-0001.jpeg', 'NORMAL2-IM-0348-0001.jpeg', 'NORMAL2-IM-0316-0001.jpeg', 'NORMAL2-IM-0145-0001.jpeg', 'IM-0089-0001.jpeg', 'IM-0070-0001.jpeg', 'NORMAL2-IM-0131-0001.jpeg', 'NORMAL2-IM-0246-0001-0001.jpeg', 'NORMAL2-IM-0369-0001.jpeg', 'NORMAL2-IM-0360-0001.jpeg', 'NORMAL2-IM-0052-0001.jpeg', 'IM-0109-0001.jpeg', 'NORMAL2-IM-0086-0001.jpeg', 'NORMAL2-IM-0060-0001.jpeg', 'NORMAL2-IM-0304-0001.jpeg', 'IM-0075-0001.jpeg', 'NORMAL2-IM-0102-0001.jpeg', 'IM-0046-0001.jpeg', 'IM-0028-0001.jpeg', 'IM-0099-0001.jpeg', 'NORMAL2-IM-0285-0001.jpeg', 'NORMAL2-IM-0335-0001.jpeg', 'NORMAL2-IM-0217-0001.jpeg', 'NORMAL2-IM-0332-0001.jpeg', 'NORMAL2-IM-0374-0001-0002.jpeg', 'NORMAL2-IM-0019-0001.jpeg', 'IM-0083-0001.jpeg', 'IM-0102-0001.jpeg', 'NORMAL2-IM-0030-0001.jpeg', 'NORMAL2-IM-0370-0001.jpeg', 'NORMAL2-IM-0135-0001.jpeg', 'NORMAL2-IM-0221-0001.jpeg', 'NORMAL2-IM-0340-0001.jpeg', 'IM-0021-0001.jpeg', 'IM-0015-0001.jpeg', 'NORMAL2-IM-0353-0001.jpeg', 'IM-0065-0001.jpeg', 'NORMAL2-IM-0309-0001.jpeg', 'NORMAL2-IM-0139-0001.jpeg', 'IM-0033-0001.jpeg', 'IM-0067-0001.jpeg', 'NORMAL2-IM-0012-0001.jpeg' ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/test/PNEUMONIA
# Subdirectories: []
# Files: ['person94_bacteria_457.jpeg', 'person133_bacteria_633.jpeg', 'person60_virus_117.jpeg', 'person1664_virus_2877.jpeg', 'person49_virus_101.jpeg', 'person122_bacteria_583.jpeg', 'person71_virus_131.jpeg', 'person111_bacteria_535.jpeg', 'person113_bacteria_543.jpeg', 'person157_bacteria_735.jpeg', 'person91_bacteria_448.jpeg', 'person1671_virus_2887.jpeg', 'person1_virus_12.jpeg', 'person1610_virus_2793.jpeg', 'person53_virus_107.jpeg', 'person172_bacteria_827.jpeg', 'person126_bacteria_598.jpeg', 'person134_bacteria_641.jpeg', 'person1669_virus_2885.jpeg', 'person100_bacteria_480.jpeg', 'person1628_virus_2822.jpeg', 'person100_bacteria_481.jpeg', 'person1608_virus_2786.jpeg', 'person81_bacteria_396.jpeg', 'person175_bacteria_835.jpeg', 'person147_bacteria_711.jpeg', 'person1653_virus_2859.jpeg', 'person96_bacteria_466.jpeg', 'person1653_virus_2858.jpeg', 'person147_bacteria_706.jpeg', 'person119_bacteria_567.jpeg', 'person122_bacteria_581.jpeg', 'person78_bacteria_381.jpeg', 'person81_bacteria_397.jpeg', 'person128_bacteria_606.jpeg', 'person130_bacteria_626.jpeg', 'person82_bacteria_402.jpeg', 'person44_virus_94.jpeg', 'person143_bacteria_687.jpeg', 'person109_bacteria_513.jpeg', 'person101_bacteria_485.jpeg', 'person85_bacteria_422.jpeg', 'person139_bacteria_663.jpeg', 'person1660_virus_2869.jpeg', 'person101_bacteria_486.jpeg', 'person145_bacteria_696.jpeg', 'person125_bacteria_594.jpeg', 'person1673_virus_2889.jpeg', 'person1661_virus_2872.jpeg', 'person146_bacteria_700.jpeg', 'person133_bacteria_635.jpeg', 'person174_bacteria_832.jpeg', 'person111_bacteria_533.jpeg', 'person1656_virus_2862.jpeg', 'person1619_virus_2806.jpeg', 'person157_bacteria_740.jpeg', 'person121_bacteria_578.jpeg', 'person1614_virus_2800.jpeg', 'person3_virus_15.jpeg', 'person150_bacteria_715.jpeg', 'person91_bacteria_445.jpeg', 'person108_bacteria_504.jpeg', 'person94_bacteria_458.jpeg', 'person139_bacteria_664.jpeg', 'person23_virus_56.jpeg', 'person72_virus_133.jpeg', 'person130_bacteria_627.jpeg', 'person3_virus_17.jpeg', 'person159_bacteria_746.jpeg', 'person139_bacteria_666.jpeg', 'person138_bacteria_659.jpeg', 'person1674_virus_2890.jpeg', 'person44_virus_93.jpeg', 'person65_virus_123.jpeg', 'person51_virus_105.jpeg', 'person90_bacteria_443.jpeg', 'person50_virus_102.jpeg', 'person83_bacteria_410.jpeg', 'person1685_virus_2903.jpeg', 'person78_bacteria_384.jpeg', 'person155_bacteria_729.jpeg', 'person136_bacteria_652.jpeg', 'person152_bacteria_723.jpeg', 'person147_bacteria_705.jpeg', 'person111_bacteria_534.jpeg', 'person80_bacteria_392.jpeg', 'person91_bacteria_449.jpeg', 'person83_bacteria_409.jpeg', 'person104_bacteria_491.jpeg', 'person78_virus_140.jpeg', 'person1631_virus_2826.jpeg', 'person1678_virus_2895.jpeg', 'person1623_virus_2813.jpeg', 'person1620_virus_2807.jpeg', 'person1633_virus_2829.jpeg', 'person1679_virus_2896.jpeg', 'person91_bacteria_447.jpeg', 'person93_bacteria_453.jpeg', 'person102_bacteria_487.jpeg', 'person110_bacteria_531.jpeg', 'person1626_virus_2818.jpeg', 'person142_bacteria_683.jpeg', 'person75_virus_136.jpeg', 'person20_virus_51.jpeg', 'person114_bacteria_544.jpeg', 'person1655_virus_2861.jpeg', 'person52_virus_106.jpeg', 'person80_bacteria_391.jpeg', 'person157_bacteria_739.jpeg', 'person43_virus_92.jpeg', 'person1637_virus_2834.jpeg', 'person94_bacteria_456.jpeg', 'person37_virus_82.jpeg', 'person119_bacteria_566.jpeg', 'person25_virus_59.jpeg', 'person109_bacteria_523.jpeg', 'person138_bacteria_657.jpeg', 'person86_bacteria_428.jpeg', 'person1669_virus_2884.jpeg', 'person88_bacteria_439.jpeg', 'person121_bacteria_580.jpeg', 'person1627_virus_2819.jpeg', 'person127_bacteria_604.jpeg', 'person26_virus_60.jpeg', 'person150_bacteria_717.jpeg', 'person136_bacteria_654.jpeg', 'person101_bacteria_483.jpeg', 'person57_virus_113.jpeg', 'person1640_virus_2839.jpeg', 'person22_virus_54.jpeg', 'person173_bacteria_831.jpeg', 'person1_virus_9.jpeg', 'person100_bacteria_482.jpeg', 'person137_bacteria_655.jpeg', 'perso ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX
# Subdirectories: ['chest_xray']
# Files: ['._chest_xray']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray
# Subdirectories: ['test', 'val', 'train']
# Files: ['._test', '._train', '._.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/test
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: ['._NORMAL', '._PNEUMONIA', '._.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/test/NORMAL
# Subdirectories: []
# Files: ['._NORMAL2-IM-0132-0001.jpeg', '._NORMAL2-IM-0241-0001.jpeg', '._NORMAL2-IM-0201-0001.jpeg', '._NORMAL2-IM-0135-0001.jpeg', '._NORMAL2-IM-0326-0001.jpeg', '._NORMAL2-IM-0327-0001.jpeg', '._NORMAL2-IM-0213-0001.jpeg', '._NORMAL2-IM-0023-0001.jpeg', '._NORMAL2-IM-0331-0001.jpeg', '._NORMAL2-IM-0274-0001.jpeg', '._IM-0097-0001.jpeg', '._NORMAL2-IM-0315-0001.jpeg', '._NORMAL2-IM-0303-0001.jpeg', '._IM-0029-0001.jpeg', '._NORMAL2-IM-0316-0001.jpeg', '._IM-0009-0001.jpeg', '._NORMAL2-IM-0105-0001.jpeg', '._NORMAL2-IM-0328-0001.jpeg', '._NORMAL2-IM-0321-0001.jpeg', '._NORMAL2-IM-0311-0001.jpeg', '._NORMAL2-IM-0029-0001.jpeg', '._NORMAL2-IM-0313-0001.jpeg', '._NORMAL2-IM-0350-0001.jpeg', '._IM-0011-0001.jpeg', '._IM-0011-0001-0001.jpeg', '._NORMAL2-IM-0120-0001.jpeg', '._IM-0031-0001.jpeg', '._IM-0073-0001.jpeg', '._NORMAL2-IM-0281-0001.jpeg', '._IM-0067-0001.jpeg', '._NORMAL2-IM-0112-0001.jpeg', '._NORMAL2-IM-0251-0001.jpeg', '._NORMAL2-IM-0349-0001.jpeg', '._IM-0089-0001.jpeg', '._NORMAL2-IM-0276-0001.jpeg', '._NORMAL2-IM-0199-0001.jpeg', '._NORMAL2-IM-0256-0001.jpeg', '._IM-0103-0001.jpeg', '._IM-0071-0001.jpeg', '._NORMAL2-IM-0196-0001.jpeg', '._IM-0036-0001.jpeg', '._NORMAL2-IM-0340-0001.jpeg', '._NORMAL2-IM-0173-0001-0001.jpeg', '._IM-0107-0001.jpeg', '._NORMAL2-IM-0360-0001.jpeg', '._NORMAL2-IM-0095-0001.jpeg', '._IM-0070-0001.jpeg', '._NORMAL2-IM-0117-0001.jpeg', '._IM-0059-0001.jpeg', '._NORMAL2-IM-0096-0001.jpeg', '._IM-0011-0001-0002.jpeg', '._NORMAL2-IM-0030-0001.jpeg', '._NORMAL2-IM-0246-0001.jpeg', '._NORMAL2-IM-0052-0001.jpeg', '._NORMAL2-IM-0210-0001.jpeg', '._NORMAL2-IM-0297-0001.jpeg', '._NORMAL2-IM-0079-0001.jpeg', '._NORMAL2-IM-0092-0001.jpeg', '._NORMAL2-IM-0150-0001.jpeg', '._IM-0021-0001.jpeg', '._NORMAL2-IM-0374-0001-0002.jpeg', '._NORMAL2-IM-0139-0001.jpeg', '._NORMAL2-IM-0233-0001.jpeg', '._NORMAL2-IM-0232-0001.jpeg', '._NORMAL2-IM-0319-0001.jpeg', '._NORMAL2-IM-0027-0001.jpeg', '._IM-0046-0001.jpeg', '._NORMAL2-IM-0376-0001.jpeg', '._NORMAL2-IM-0339-0001.jpeg', '._NORMAL2-IM-0348-0001.jpeg', '._NORMAL2-IM-0378-0001.jpeg', '._NORMAL2-IM-0351-0001.jpeg', '._NORMAL2-IM-0273-0001.jpeg', '._NORMAL2-IM-0246-0001-0002.jpeg', '._NORMAL2-IM-0195-0001.jpeg', '._NORMAL2-IM-0086-0001.jpeg', '._NORMAL2-IM-0364-0001.jpeg', '._NORMAL2-IM-0329-0001.jpeg', '._NORMAL2-IM-0206-0001.jpeg', '._NORMAL2-IM-0285-0001.jpeg', '._IM-0049-0001.jpeg', '._NORMAL2-IM-0341-0001.jpeg', '._IM-0086-0001.jpeg', '._NORMAL2-IM-0332-0001.jpeg', '._NORMAL2-IM-0352-0001.jpeg', '._NORMAL2-IM-0381-0001.jpeg', '._NORMAL2-IM-0229-0001.jpeg', '._NORMAL2-IM-0323-0001.jpeg', '._IM-0069-0001.jpeg', '._NORMAL2-IM-0102-0001.jpeg', '._IM-0043-0001.jpeg', '._NORMAL2-IM-0368-0001.jpeg', '._NORMAL2-IM-0359-0001.jpeg', '._NORMAL2-IM-0019-0001.jpeg', '._IM-0095-0001.jpeg', '._NORMAL2-IM-0259-0001.jpeg', '._NORMAL2-IM-0307-0001.jpeg', '._NORMAL2-IM-0362-0001.jpeg', '._IM-0003-0001.jpeg', '._IM-0091-0001.jpeg', '._IM-0005-0001.jpeg', '._NORMAL2-IM-0058-0001.jpeg', '._NORMAL2-IM-0279-0001.jpeg', '._NORMAL2-IM-0292-0001.jpeg', '._IM-0077-0001.jpeg', '._IM-0023-0001.jpeg', '._NORMAL2-IM-0335-0001.jpeg', '._IM-0111-0001.jpeg', '._IM-0101-0001.jpeg', '._NORMAL2-IM-0059-0001.jpeg', '._NORMAL2-IM-0060-0001.jpeg', '._NORMAL2-IM-0361-0001.jpeg', '._NORMAL2-IM-0066-0001.jpeg', '._IM-0099-0001.jpeg', '._NORMAL2-IM-0130-0001.jpeg', '._NORMAL2-IM-0107-0001.jpeg', '._NORMAL2-IM-0141-0001.jpeg', '._NORMAL2-IM-0337-0001.jpeg', '._NORMAL2-IM-0111-0001.jpeg', '._NORMAL2-IM-0312-0001.jpeg', '._IM-0087-0001.jpeg', '._IM-0041-0001.jpeg', '._NORMAL2-IM-0207-0001.jpeg', '._NORMAL2-IM-0346-0001.jpeg', '._NORMAL2-IM-0278-0001.jpeg', '._IM-0079-0001.jpeg', '._IM-0007-0001.jpeg', '._IM-0102-0001.jpeg', '._NORMAL2-IM-0310-0001.jpeg', '._NORMAL2-IM-0333-0001.jpeg', '._IM-0033-0001.jpeg', '._IM-0039-0001.jpeg', '._IM-0065-0001.jpeg', '._NORMAL2-IM-0013-0001.jpeg', '._NORMAL2-IM-0317-0001.jpeg', '._NORMAL2-IM-0301-0001.jpeg', '._NORMAL2-IM-0374-0001.jpeg', '._NORMAL2-IM-0222-0001.jpeg', ' ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/test/PNEUMONIA
# Subdirectories: []
# Files: ['._person146_bacteria_700.jpeg', '._person86_bacteria_429.jpeg', '._person44_virus_93.jpeg', '._person95_bacteria_463.jpeg', '._person94_bacteria_457.jpeg', '._person78_bacteria_384.jpeg', '._person48_virus_100.jpeg', '._person1635_virus_2831.jpeg', '._person147_bacteria_711.jpeg', '._person59_virus_116.jpeg', '._person130_bacteria_626.jpeg', '._person89_bacteria_440.jpeg', '._person136_bacteria_650.jpeg', '._person142_bacteria_682.jpeg', '._person88_bacteria_439.jpeg', '._person99_bacteria_474.jpeg', '._person83_bacteria_409.jpeg', '._person139_bacteria_663.jpeg', '._person103_bacteria_488.jpeg', '._person103_bacteria_490.jpeg', '._person91_bacteria_445.jpeg', '._person69_virus_129.jpeg', '._person150_bacteria_715.jpeg', '._person135_bacteria_646.jpeg', '._person10_virus_35.jpeg', '._person82_bacteria_402.jpeg', '._person87_bacteria_433.jpeg', '._person1_virus_7.jpeg', '._person86_bacteria_428.jpeg', '._person41_virus_88.jpeg', '._person1640_virus_2839.jpeg', '._person128_bacteria_605.jpeg', '._person175_bacteria_834.jpeg', '._person113_bacteria_541.jpeg', '._person78_bacteria_378.jpeg', '._person120_bacteria_571.jpeg', '._person1632_virus_2827.jpeg', '._person152_bacteria_720.jpeg', '._person173_bacteria_830.jpeg', '._person1650_virus_2854.jpeg', '._person109_bacteria_517.jpeg', '._person11_virus_38.jpeg', '._person151_bacteria_718.jpeg', '._person65_virus_123.jpeg', '._person100_bacteria_479.jpeg', '._person1670_virus_2886.jpeg', '._person1608_virus_2786.jpeg', '._person122_bacteria_585.jpeg', '._person81_bacteria_395.jpeg', '._person60_virus_117.jpeg', '._person127_bacteria_603.jpeg', '._person1678_virus_2895.jpeg', '._person45_virus_95.jpeg', '._person3_virus_15.jpeg', '._person123_bacteria_587.jpeg', '._person161_bacteria_757.jpeg', '._person100_bacteria_478.jpeg', '._person140_bacteria_667.jpeg', '._person100_bacteria_481.jpeg', '._person1612_virus_2798.jpeg', '._person139_bacteria_662.jpeg', '._person113_bacteria_542.jpeg', '._person28_virus_62.jpeg', '._person20_virus_51.jpeg', '._person53_virus_108.jpeg', '._person152_bacteria_721.jpeg', '._person93_bacteria_454.jpeg', '._person122_bacteria_584.jpeg', '._person1614_virus_2800.jpeg', '._person57_virus_113.jpeg', '._person108_bacteria_506.jpeg', '._person83_bacteria_410.jpeg', '._person139_bacteria_661.jpeg', '._person44_virus_94.jpeg', '._person152_bacteria_724.jpeg', '._person38_virus_84.jpeg', '._person139_bacteria_665.jpeg', '._person120_bacteria_573.jpeg', '._person85_bacteria_421.jpeg', '._person133_bacteria_638.jpeg', '._person96_bacteria_465.jpeg', '._person38_virus_83.jpeg', '._person172_bacteria_828.jpeg', '._person141_bacteria_678.jpeg', '._person130_bacteria_628.jpeg', '._person150_bacteria_716.jpeg', '._person127_bacteria_602.jpeg', '._person157_bacteria_739.jpeg', '._person128_bacteria_608.jpeg', '._person139_bacteria_664.jpeg', '._person109_bacteria_523.jpeg', '._person80_bacteria_390.jpeg', '._person91_bacteria_449.jpeg', '._person43_virus_92.jpeg', '._person114_bacteria_546.jpeg', '._person152_bacteria_722.jpeg', '._person111_bacteria_536.jpeg', '._person133_bacteria_634.jpeg', '._person26_virus_60.jpeg', '._person119_bacteria_568.jpeg', '._person114_bacteria_545.jpeg', '._person157_bacteria_740.jpeg', '._person121_bacteria_578.jpeg', '._person113_bacteria_543.jpeg', '._person85_bacteria_417.jpeg', '._person1628_virus_2821.jpeg', '._person96_bacteria_466.jpeg', '._person140_bacteria_668.jpeg', '._person108_bacteria_507.jpeg', '._person134_bacteria_642.jpeg', '._person100_bacteria_477.jpeg', '._person74_virus_135.jpeg', '._person114_bacteria_544.jpeg', '._person78_bacteria_381.jpeg', '._person103_bacteria_489.jpeg', '._person21_virus_53.jpeg', '._person130_bacteria_627.jpeg', '._person1662_virus_2875.jpeg', '._person1656_virus_2862.jpeg', '._person1_virus_9.jpeg', '._person85_bacteria_424.jpeg', '._person173_bacteria_829.jpeg', '._person100_bacteria_475.jpeg', '._person1615_virus_2801.jpeg', '._person153_bacteria_725.jpeg', '._person110_bacteria ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/val
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: ['._.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/val/NORMAL
# Subdirectories: []
# Files: ['._NORMAL2-IM-1440-0001.jpeg', '._NORMAL2-IM-1442-0001.jpeg', '._NORMAL2-IM-1427-0001.jpeg', '._NORMAL2-IM-1437-0001.jpeg', '._NORMAL2-IM-1438-0001.jpeg', '._NORMAL2-IM-1431-0001.jpeg', '._NORMAL2-IM-1430-0001.jpeg', '._.DS_Store', '._NORMAL2-IM-1436-0001.jpeg']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/val/PNEUMONIA
# Subdirectories: []
# Files: ['._person1951_bacteria_4882.jpeg', '._person1946_bacteria_4875.jpeg', '._person1952_bacteria_4883.jpeg', '._person1954_bacteria_4886.jpeg', '._person1947_bacteria_4876.jpeg', '._person1949_bacteria_4880.jpeg', '._person1950_bacteria_4881.jpeg', '._person1946_bacteria_4874.jpeg', '._.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/train
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: ['._NORMAL', '._PNEUMONIA', '._.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/train/NORMAL
# Subdirectories: []
# Files: ['._NORMAL2-IM-1094-0001-0001.jpeg', '._IM-0746-0001.jpeg', '._NORMAL2-IM-1221-0001.jpeg', '._NORMAL2-IM-0568-0001.jpeg', '._NORMAL2-IM-1348-0001.jpeg', '._IM-0717-0001.jpeg', '._IM-0410-0001.jpeg', '._NORMAL2-IM-1267-0001.jpeg', '._NORMAL2-IM-0665-0001.jpeg', '._IM-0561-0001.jpeg', '._IM-0464-0001.jpeg', '._IM-0591-0001.jpeg', '._IM-0387-0001.jpeg', '._NORMAL2-IM-1250-0001.jpeg', '._IM-0293-0001.jpeg', '._IM-0645-0001.jpeg', '._NORMAL2-IM-0486-0001.jpeg', '._IM-0343-0001.jpeg', '._IM-0477-0001.jpeg', '._IM-0615-0001.jpeg', '._NORMAL2-IM-0987-0001.jpeg', '._IM-0578-0001.jpeg', '._IM-0346-0001.jpeg', '._NORMAL2-IM-0869-0001.jpeg', '._NORMAL2-IM-0811-0001.jpeg', '._IM-0337-0001.jpeg', '._IM-0727-0001.jpeg', '._IM-0439-0001-0002.jpeg', '._IM-0458-0001.jpeg', '._NORMAL2-IM-0875-0001.jpeg', '._NORMAL2-IM-0772-0001.jpeg', '._IM-0434-0001.jpeg', '._NORMAL2-IM-1314-0001.jpeg', '._IM-0753-0001.jpeg', '._NORMAL2-IM-0804-0001.jpeg', '._NORMAL2-IM-0775-0001.jpeg', '._NORMAL2-IM-0449-0001.jpeg', '._IM-0219-0001.jpeg', '._IM-0712-0001.jpeg', '._IM-0467-0001.jpeg', '._NORMAL2-IM-0594-0001.jpeg', '._IM-0629-0001.jpeg', '._NORMAL2-IM-0941-0001.jpeg', '._IM-0286-0001.jpeg', '._IM-0133-0001.jpeg', '._NORMAL2-IM-0862-0001.jpeg', '._NORMAL2-IM-1096-0001.jpeg', '._NORMAL2-IM-0529-0001.jpeg', '._NORMAL2-IM-1266-0001-0001.jpeg', '._NORMAL2-IM-0926-0001.jpeg', '._NORMAL2-IM-0530-0001.jpeg', '._NORMAL2-IM-0416-0001.jpeg', '._IM-0314-0001.jpeg', '._NORMAL2-IM-0829-0001.jpeg', '._IM-0519-0001-0001.jpeg', '._IM-0552-0001.jpeg', '._NORMAL2-IM-0539-0001.jpeg', '._NORMAL2-IM-1322-0001.jpeg', '._IM-0480-0001.jpeg', '._NORMAL2-IM-1008-0001.jpeg', '._IM-0531-0001-0001.jpeg', '._NORMAL2-IM-0727-0001.jpeg', '._NORMAL2-IM-0872-0001.jpeg', '._IM-0618-0001-0002.jpeg', '._NORMAL2-IM-1257-0001.jpeg', '._NORMAL2-IM-1197-0001.jpeg', '._IM-0524-0001.jpeg', '._IM-0535-0001.jpeg', '._NORMAL2-IM-0693-0001.jpeg', '._IM-0466-0001.jpeg', '._NORMAL2-IM-0481-0001.jpeg', '._IM-0525-0001-0001.jpeg', '._IM-0548-0001.jpeg', '._NORMAL2-IM-1338-0001.jpeg', '._NORMAL2-IM-0808-0001.jpeg', '._IM-0551-0001-0001.jpeg', '._NORMAL2-IM-0858-0001.jpeg', '._IM-0455-0001.jpeg', '._NORMAL2-IM-0518-0001.jpeg', '._IM-0691-0001.jpeg', '._IM-0553-0001-0002.jpeg', '._NORMAL2-IM-1108-0001.jpeg', '._IM-0205-0001.jpeg', '._NORMAL2-IM-1258-0001-0001.jpeg', '._IM-0453-0001-0002.jpeg', '._NORMAL2-IM-1278-0001.jpeg', '._IM-0656-0001.jpeg', '._NORMAL2-IM-1422-0001.jpeg', '._NORMAL2-IM-0851-0001-0002.jpeg', '._NORMAL2-IM-0412-0001.jpeg', '._NORMAL2-IM-1356-0001.jpeg', '._IM-0220-0001.jpeg', '._NORMAL2-IM-0929-0001.jpeg', '._IM-0695-0001.jpeg', '._IM-0656-0001-0002.jpeg', '._NORMAL2-IM-0924-0001.jpeg', '._NORMAL2-IM-0576-0001.jpeg', '._NORMAL2-IM-1058-0001.jpeg', '._IM-0590-0001.jpeg', '._NORMAL2-IM-1154-0001.jpeg', '._IM-0251-0001.jpeg', '._NORMAL2-IM-0465-0001.jpeg', '._NORMAL2-IM-0395-0001-0001.jpeg', '._NORMAL2-IM-1127-0001.jpeg', '._NORMAL2-IM-0396-0001.jpeg', '._IM-0311-0001.jpeg', '._NORMAL2-IM-1335-0001.jpeg', '._NORMAL2-IM-0537-0001.jpeg', '._NORMAL2-IM-0969-0001.jpeg', '._IM-0151-0001.jpeg', '._IM-0509-0001-0001.jpeg', '._NORMAL2-IM-1176-0001.jpeg', '._NORMAL2-IM-0472-0001.jpeg', '._IM-0536-0001.jpeg', '._IM-0185-0001.jpeg', '._IM-0341-0001.jpeg', '._NORMAL2-IM-0619-0001.jpeg', '._NORMAL2-IM-0391-0001.jpeg', '._NORMAL2-IM-0659-0001.jpeg', '._NORMAL2-IM-0954-0001.jpeg', '._NORMAL2-IM-0725-0001.jpeg', '._IM-0433-0001.jpeg', '._IM-0338-0001.jpeg', '._IM-0239-0001.jpeg', '._NORMAL2-IM-0395-0001-0002.jpeg', '._NORMAL2-IM-1067-0001-0001.jpeg', '._IM-0238-0001.jpeg', '._NORMAL2-IM-0508-0001.jpeg', '._NORMAL2-IM-0825-0001.jpeg', '._IM-0272-0001.jpeg', '._IM-0499-0001-0002.jpeg', '._NORMAL2-IM-1030-0001.jpeg', '._IM-0295-0001.jpeg', '._IM-0608-0001-0002.jpeg', '._NORMAL2-IM-0793-0001.jpeg', '._IM-0718-0001.jpeg', '._IM-0647-0001.jpeg', '._NORMAL2-IM-0900-0001.jpeg', '._IM-0631-0001.jpeg', '._IM-0728-0001.jpeg', '._NORMAL2-IM-1014-0001.jpeg', '._IM-0445-0001.jpeg', '._IM-0383-0001.jpeg', '._NORMAL2-IM-11 ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/__MACOSX/chest_xray/train/PNEUMONIA
# Subdirectories: []
# Files: ['._person371_bacteria_1702.jpeg', '._person1323_bacteria_3361.jpeg', '._person1056_virus_1755.jpeg', '._person58_bacteria_277.jpeg', '._person357_bacteria_1639.jpeg', '._person466_virus_960.jpeg', '._person27_bacteria_138.jpeg', '._person1562_bacteria_4081.jpeg', '._person419_virus_859.jpeg', '._person1670_bacteria_4428.jpeg', '._person1545_bacteria_4042.jpeg', '._person486_bacteria_2052.jpeg', '._person1757_bacteria_4599.jpeg', '._person741_bacteria_2644.jpeg', '._person1405_bacteria_3564.jpeg', '._person1585_bacteria_4149.jpeg', '._person1684_bacteria_4463.jpeg', '._person531_bacteria_2238.jpeg', '._person465_bacteria_1976.jpeg', '._person1472_bacteria_3834.jpeg', '._person547_virus_1086.jpeg', '._person316_bacteria_1469.jpeg', '._person1206_bacteria_3158.jpeg', '._person371_bacteria_1699.jpeg', '._person1663_bacteria_4412.jpeg', '._person1574_bacteria_4118.jpeg', '._person470_bacteria_1996.jpeg', '._person859_virus_1504.jpeg', '._person1087_bacteria_3027.jpeg', '._person778_bacteria_2682.jpeg', '._person264_virus_547.jpeg', '._person1702_bacteria_4510.jpeg', '._person571_virus_1114.jpeg', '._person1483_virus_2574.jpeg', '._person1888_bacteria_4775.jpeg', '._person115_virus_218.jpeg', '._person1230_virus_2081.jpeg', '._person487_bacteria_2058.jpeg', '._person588_bacteria_2423.jpeg', '._person1465_virus_2532.jpeg', '._person1165_virus_1959.jpeg', '._person306_bacteria_1439.jpeg', '._person1180_virus_2012.jpeg', '._person1209_bacteria_3161.jpeg', '._person19_bacteria_61.jpeg', '._person811_bacteria_2721.jpeg', '._person940_virus_1609.jpeg', '._person539_bacteria_2270.jpeg', '._person1932_bacteria_4843.jpeg', '._person658_virus_1241.jpeg', '._person515_bacteria_2185.jpeg', '._person501_virus_1010.jpeg', '._person1176_bacteria_3123.jpeg', '._person1287_bacteria_3250.jpeg', '._person1295_bacteria_3258.jpeg', '._person1413_bacteria_3620.jpeg', '._person770_bacteria_2674.jpeg', '._person371_bacteria_1701.jpeg', '._person1147_virus_1917.jpeg', '._person325_virus_664.jpeg', '._person1865_bacteria_4739.jpeg', '._person671_virus_1260.jpeg', '._person1184_virus_2019.jpeg', '._person411_bacteria_1826.jpeg', '._person1455_virus_2488.jpeg', '._person266_bacteria_1245.jpeg', '._person483_virus_985.jpeg', '._person366_virus_746.jpeg', '._person1164_virus_1952.jpeg', '._person759_virus_1387.jpeg', '._person342_virus_702.jpeg', '._person629_bacteria_2508.jpeg', '._person1227_virus_2078.jpeg', '._person1372_bacteria_3498.jpeg', '._person278_virus_572.jpeg', '._person1183_bacteria_3131.jpeg', '._person1469_bacteria_3827.jpeg', '._person364_bacteria_1658.jpeg', '._person807_virus_1441.jpeg', '._person281_bacteria_1329.jpeg', '._person1232_virus_2089.jpeg', '._person1021_virus_1711.jpeg', '._person393_bacteria_1789.jpeg', '._person1314_virus_2266.jpeg', '._person1482_virus_2572.jpeg', '._person1540_virus_2680.jpeg', '._person1244_virus_2111.jpeg', '._person913_virus_1570.jpeg', '._person566_virus_1106.jpeg', '._person1151_virus_1928.jpeg', '._person1476_bacteria_3842.jpeg', '._person1619_bacteria_4261.jpeg', '._person26_bacteria_127.jpeg', '._person820_virus_1456.jpeg', '._person605_bacteria_2464.jpeg', '._person337_bacteria_1564.jpeg', '._person1591_virus_2765.jpeg', '._person298_bacteria_1408.jpeg', '._person858_bacteria_2780.jpeg', '._person635_bacteria_2526.jpeg', '._person517_virus_1035.jpeg', '._person1372_bacteria_3499.jpeg', '._person1119_virus_1844.jpeg', '._person1157_virus_1937.jpeg', '._person1597_bacteria_4191.jpeg', '._person1429_bacteria_3688.jpeg', '._person933_bacteria_2858.jpeg', '._person111_virus_212.jpeg', '._person1160_virus_1947.jpeg', '._person1344_bacteria_3421.jpeg', '._person48_bacteria_231.jpeg', '._person1611_bacteria_4241.jpeg', '._person299_bacteria_1417.jpeg', '._person472_bacteria_2015.jpeg', '._person471_virus_968.jpeg', '._person486_virus_990.jpeg', '._person135_virus_270.jpeg', '._person470_bacteria_2000.jpeg', '._person701_bacteria_2600.jpeg', '._person605_bacteria_2468.jpeg', '._person441_virus_896.jpe ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray
# Subdirectories: ['test', 'val', 'train']
# Files: ['.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/test
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: ['.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/test/NORMAL
# Subdirectories: []
# Files: ['NORMAL2-IM-0251-0001.jpeg', 'NORMAL2-IM-0286-0001.jpeg', 'NORMAL2-IM-0343-0001.jpeg', 'IM-0016-0001.jpeg', 'NORMAL2-IM-0326-0001.jpeg', 'NORMAL2-IM-0219-0001.jpeg', 'NORMAL2-IM-0195-0001.jpeg', 'NORMAL2-IM-0206-0001.jpeg', 'IM-0025-0001.jpeg', 'NORMAL2-IM-0105-0001.jpeg', 'NORMAL2-IM-0096-0001.jpeg', 'NORMAL2-IM-0110-0001.jpeg', 'NORMAL2-IM-0058-0001.jpeg', 'NORMAL2-IM-0374-0001-0001.jpeg', 'NORMAL2-IM-0337-0001.jpeg', 'IM-0061-0001.jpeg', 'NORMAL2-IM-0079-0001.jpeg', 'IM-0069-0001.jpeg', 'IM-0022-0001.jpeg', 'IM-0019-0001.jpeg', 'NORMAL2-IM-0317-0001.jpeg', 'IM-0011-0001-0001.jpeg', 'IM-0097-0001.jpeg', 'NORMAL2-IM-0073-0001.jpeg', 'NORMAL2-IM-0290-0001.jpeg', 'IM-0029-0001.jpeg', 'NORMAL2-IM-0381-0001.jpeg', 'IM-0093-0001.jpeg', 'NORMAL2-IM-0196-0001.jpeg', 'NORMAL2-IM-0350-0001.jpeg', 'NORMAL2-IM-0302-0001.jpeg', 'IM-0033-0001-0002.jpeg', 'IM-0087-0001.jpeg', 'NORMAL2-IM-0305-0001.jpeg', 'NORMAL2-IM-0362-0001.jpeg', 'IM-0110-0001.jpeg', 'IM-0027-0001.jpeg', 'NORMAL2-IM-0338-0001.jpeg', 'IM-0037-0001.jpeg', 'NORMAL2-IM-0132-0001.jpeg', 'NORMAL2-IM-0129-0001.jpeg', 'NORMAL2-IM-0041-0001.jpeg', 'NORMAL2-IM-0321-0001.jpeg', 'NORMAL2-IM-0271-0001.jpeg', 'NORMAL2-IM-0359-0001.jpeg', 'NORMAL2-IM-0028-0001.jpeg', 'NORMAL2-IM-0033-0001.jpeg', 'NORMAL2-IM-0346-0001.jpeg', 'IM-0103-0001.jpeg', 'IM-0007-0001.jpeg', 'NORMAL2-IM-0029-0001.jpeg', 'NORMAL2-IM-0364-0001.jpeg', 'NORMAL2-IM-0198-0001.jpeg', 'IM-0111-0001.jpeg', 'IM-0095-0001.jpeg', 'NORMAL2-IM-0282-0001.jpeg', 'NORMAL2-IM-0051-0001.jpeg', 'NORMAL2-IM-0345-0001.jpeg', 'NORMAL2-IM-0307-0001.jpeg', 'NORMAL2-IM-0111-0001.jpeg', 'NORMAL2-IM-0238-0001.jpeg', 'IM-0017-0001.jpeg', 'NORMAL2-IM-0325-0001.jpeg', 'IM-0050-0001.jpeg', 'NORMAL2-IM-0213-0001.jpeg', 'NORMAL2-IM-0120-0001.jpeg', 'NORMAL2-IM-0233-0001.jpeg', 'NORMAL2-IM-0007-0001.jpeg', 'NORMAL2-IM-0366-0001.jpeg', 'NORMAL2-IM-0330-0001.jpeg', 'NORMAL2-IM-0130-0001.jpeg', 'NORMAL2-IM-0066-0001.jpeg', 'NORMAL2-IM-0210-0001.jpeg', 'NORMAL2-IM-0311-0001.jpeg', 'IM-0105-0001.jpeg', 'NORMAL2-IM-0278-0001.jpeg', 'NORMAL2-IM-0322-0001.jpeg', 'NORMAL2-IM-0013-0001.jpeg', 'NORMAL2-IM-0267-0001.jpeg', 'NORMAL2-IM-0313-0001.jpeg', 'NORMAL2-IM-0376-0001.jpeg', 'IM-0036-0001.jpeg', 'NORMAL2-IM-0232-0001.jpeg', 'NORMAL2-IM-0329-0001.jpeg', 'NORMAL2-IM-0339-0001.jpeg', 'NORMAL2-IM-0327-0001.jpeg', 'IM-0091-0001.jpeg', 'NORMAL2-IM-0207-0001.jpeg', 'NORMAL2-IM-0275-0001.jpeg', 'NORMAL2-IM-0274-0001.jpeg', 'NORMAL2-IM-0333-0001.jpeg', 'IM-0045-0001.jpeg', 'IM-0063-0001.jpeg', 'NORMAL2-IM-0292-0001.jpeg', 'NORMAL2-IM-0341-0001.jpeg', 'IM-0009-0001.jpeg', 'NORMAL2-IM-0315-0001.jpeg', 'NORMAL2-IM-0280-0001.jpeg', 'NORMAL2-IM-0222-0001.jpeg', 'NORMAL2-IM-0287-0001.jpeg', 'NORMAL2-IM-0201-0001.jpeg', 'IM-0101-0001.jpeg', 'NORMAL2-IM-0380-0001.jpeg', 'NORMAL2-IM-0123-0001.jpeg', 'IM-0086-0001.jpeg', 'NORMAL2-IM-0352-0001.jpeg', 'NORMAL2-IM-0368-0001.jpeg', 'IM-0013-0001.jpeg', 'NORMAL2-IM-0348-0001.jpeg', 'NORMAL2-IM-0316-0001.jpeg', 'NORMAL2-IM-0145-0001.jpeg', 'IM-0089-0001.jpeg', 'IM-0070-0001.jpeg', 'NORMAL2-IM-0131-0001.jpeg', 'NORMAL2-IM-0246-0001-0001.jpeg', 'NORMAL2-IM-0369-0001.jpeg', 'NORMAL2-IM-0360-0001.jpeg', 'NORMAL2-IM-0052-0001.jpeg', 'IM-0109-0001.jpeg', 'NORMAL2-IM-0086-0001.jpeg', 'NORMAL2-IM-0060-0001.jpeg', 'NORMAL2-IM-0304-0001.jpeg', 'IM-0075-0001.jpeg', 'NORMAL2-IM-0102-0001.jpeg', 'IM-0046-0001.jpeg', 'IM-0028-0001.jpeg', 'IM-0099-0001.jpeg', 'NORMAL2-IM-0285-0001.jpeg', 'NORMAL2-IM-0335-0001.jpeg', 'NORMAL2-IM-0217-0001.jpeg', 'NORMAL2-IM-0332-0001.jpeg', 'NORMAL2-IM-0374-0001-0002.jpeg', 'NORMAL2-IM-0019-0001.jpeg', 'IM-0083-0001.jpeg', 'IM-0102-0001.jpeg', 'NORMAL2-IM-0030-0001.jpeg', 'NORMAL2-IM-0370-0001.jpeg', 'NORMAL2-IM-0135-0001.jpeg', 'NORMAL2-IM-0221-0001.jpeg', 'NORMAL2-IM-0340-0001.jpeg', 'IM-0021-0001.jpeg', 'IM-0015-0001.jpeg', 'NORMAL2-IM-0353-0001.jpeg', 'IM-0065-0001.jpeg', 'NORMAL2-IM-0309-0001.jpeg', 'NORMAL2-IM-0139-0001.jpeg', 'IM-0033-0001.jpeg', 'IM-0067-0001.jpeg', 'NORMAL2-IM-0012-0001.jpeg' ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/test/PNEUMONIA
# Subdirectories: []
# Files: ['person94_bacteria_457.jpeg', 'person133_bacteria_633.jpeg', 'person60_virus_117.jpeg', 'person1664_virus_2877.jpeg', 'person49_virus_101.jpeg', 'person122_bacteria_583.jpeg', 'person71_virus_131.jpeg', 'person111_bacteria_535.jpeg', 'person113_bacteria_543.jpeg', 'person157_bacteria_735.jpeg', 'person91_bacteria_448.jpeg', 'person1671_virus_2887.jpeg', 'person1_virus_12.jpeg', 'person1610_virus_2793.jpeg', 'person53_virus_107.jpeg', 'person172_bacteria_827.jpeg', 'person126_bacteria_598.jpeg', 'person134_bacteria_641.jpeg', 'person1669_virus_2885.jpeg', 'person100_bacteria_480.jpeg', 'person1628_virus_2822.jpeg', 'person100_bacteria_481.jpeg', 'person1608_virus_2786.jpeg', 'person81_bacteria_396.jpeg', 'person175_bacteria_835.jpeg', 'person147_bacteria_711.jpeg', 'person1653_virus_2859.jpeg', 'person96_bacteria_466.jpeg', 'person1653_virus_2858.jpeg', 'person147_bacteria_706.jpeg', 'person119_bacteria_567.jpeg', 'person122_bacteria_581.jpeg', 'person78_bacteria_381.jpeg', 'person81_bacteria_397.jpeg', 'person128_bacteria_606.jpeg', 'person130_bacteria_626.jpeg', 'person82_bacteria_402.jpeg', 'person44_virus_94.jpeg', 'person143_bacteria_687.jpeg', 'person109_bacteria_513.jpeg', 'person101_bacteria_485.jpeg', 'person85_bacteria_422.jpeg', 'person139_bacteria_663.jpeg', 'person1660_virus_2869.jpeg', 'person101_bacteria_486.jpeg', 'person145_bacteria_696.jpeg', 'person125_bacteria_594.jpeg', 'person1673_virus_2889.jpeg', 'person1661_virus_2872.jpeg', 'person146_bacteria_700.jpeg', 'person133_bacteria_635.jpeg', 'person174_bacteria_832.jpeg', 'person111_bacteria_533.jpeg', 'person1656_virus_2862.jpeg', 'person1619_virus_2806.jpeg', 'person157_bacteria_740.jpeg', 'person121_bacteria_578.jpeg', 'person1614_virus_2800.jpeg', 'person3_virus_15.jpeg', 'person150_bacteria_715.jpeg', 'person91_bacteria_445.jpeg', 'person108_bacteria_504.jpeg', 'person94_bacteria_458.jpeg', 'person139_bacteria_664.jpeg', 'person23_virus_56.jpeg', 'person72_virus_133.jpeg', 'person130_bacteria_627.jpeg', 'person3_virus_17.jpeg', 'person159_bacteria_746.jpeg', 'person139_bacteria_666.jpeg', 'person138_bacteria_659.jpeg', 'person1674_virus_2890.jpeg', 'person44_virus_93.jpeg', 'person65_virus_123.jpeg', 'person51_virus_105.jpeg', 'person90_bacteria_443.jpeg', 'person50_virus_102.jpeg', 'person83_bacteria_410.jpeg', 'person1685_virus_2903.jpeg', 'person78_bacteria_384.jpeg', 'person155_bacteria_729.jpeg', 'person136_bacteria_652.jpeg', 'person152_bacteria_723.jpeg', 'person147_bacteria_705.jpeg', 'person111_bacteria_534.jpeg', 'person80_bacteria_392.jpeg', 'person91_bacteria_449.jpeg', 'person83_bacteria_409.jpeg', 'person104_bacteria_491.jpeg', 'person78_virus_140.jpeg', 'person1631_virus_2826.jpeg', 'person1678_virus_2895.jpeg', 'person1623_virus_2813.jpeg', 'person1620_virus_2807.jpeg', 'person1633_virus_2829.jpeg', 'person1679_virus_2896.jpeg', 'person91_bacteria_447.jpeg', 'person93_bacteria_453.jpeg', 'person102_bacteria_487.jpeg', 'person110_bacteria_531.jpeg', 'person1626_virus_2818.jpeg', 'person142_bacteria_683.jpeg', 'person75_virus_136.jpeg', 'person20_virus_51.jpeg', 'person114_bacteria_544.jpeg', 'person1655_virus_2861.jpeg', 'person52_virus_106.jpeg', 'person80_bacteria_391.jpeg', 'person157_bacteria_739.jpeg', 'person43_virus_92.jpeg', 'person1637_virus_2834.jpeg', 'person94_bacteria_456.jpeg', 'person37_virus_82.jpeg', 'person119_bacteria_566.jpeg', 'person25_virus_59.jpeg', 'person109_bacteria_523.jpeg', 'person138_bacteria_657.jpeg', 'person86_bacteria_428.jpeg', 'person1669_virus_2884.jpeg', 'person88_bacteria_439.jpeg', 'person121_bacteria_580.jpeg', 'person1627_virus_2819.jpeg', 'person127_bacteria_604.jpeg', 'person26_virus_60.jpeg', 'person150_bacteria_717.jpeg', 'person136_bacteria_654.jpeg', 'person101_bacteria_483.jpeg', 'person57_virus_113.jpeg', 'person1640_virus_2839.jpeg', 'person22_virus_54.jpeg', 'person173_bacteria_831.jpeg', 'person1_virus_9.jpeg', 'person100_bacteria_482.jpeg', 'person137_bacteria_655.jpeg', 'perso ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/val
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: ['.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/val/NORMAL
# Subdirectories: []
# Files: ['NORMAL2-IM-1431-0001.jpeg', 'NORMAL2-IM-1440-0001.jpeg', 'NORMAL2-IM-1427-0001.jpeg', 'NORMAL2-IM-1436-0001.jpeg', 'NORMAL2-IM-1437-0001.jpeg', 'NORMAL2-IM-1430-0001.jpeg', 'NORMAL2-IM-1442-0001.jpeg', 'NORMAL2-IM-1438-0001.jpeg', '.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/val/PNEUMONIA
# Subdirectories: []
# Files: ['person1947_bacteria_4876.jpeg', 'person1946_bacteria_4875.jpeg', 'person1951_bacteria_4882.jpeg', 'person1946_bacteria_4874.jpeg', 'person1952_bacteria_4883.jpeg', 'person1949_bacteria_4880.jpeg', 'person1950_bacteria_4881.jpeg', '.DS_Store', 'person1954_bacteria_4886.jpeg']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/train
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: ['.DS_Store']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/train/NORMAL
# Subdirectories: []
# Files: ['IM-0417-0001.jpeg', 'NORMAL2-IM-1301-0001.jpeg', 'IM-0375-0001.jpeg', 'NORMAL2-IM-1314-0001.jpeg', 'IM-0286-0001.jpeg', 'NORMAL2-IM-0671-0001.jpeg', 'NORMAL2-IM-0957-0001.jpeg', 'IM-0137-0001.jpeg', 'NORMAL2-IM-1054-0001.jpeg', 'IM-0717-0001.jpeg', 'NORMAL2-IM-0416-0001-0001.jpeg', 'NORMAL2-IM-0904-0001.jpeg', 'IM-0300-0001.jpeg', 'IM-0622-0001-0002.jpeg', 'IM-0549-0001.jpeg', 'IM-0474-0001.jpeg', 'NORMAL2-IM-0652-0001.jpeg', 'IM-0302-0001.jpeg', 'NORMAL2-IM-0601-0001.jpeg', 'IM-0477-0001.jpeg', 'NORMAL2-IM-1345-0001-0001.jpeg', 'NORMAL2-IM-0425-0001.jpeg', 'IM-0604-0001.jpeg', 'NORMAL2-IM-1136-0001.jpeg', 'NORMAL2-IM-0618-0001.jpeg', 'NORMAL2-IM-0960-0001.jpeg', 'NORMAL2-IM-0480-0001.jpeg', 'NORMAL2-IM-0573-0001.jpeg', 'IM-0666-0001-0001.jpeg', 'NORMAL2-IM-1260-0001.jpeg', 'IM-0236-0001.jpeg', 'IM-0579-0001.jpeg', 'NORMAL2-IM-0803-0001.jpeg', 'NORMAL2-IM-0999-0001.jpeg', 'NORMAL2-IM-0552-0001.jpeg', 'IM-0670-0001.jpeg', 'IM-0346-0001.jpeg', 'NORMAL2-IM-1209-0001.jpeg', 'IM-0493-0001.jpeg', 'NORMAL2-IM-0741-0001.jpeg', 'NORMAL2-IM-1108-0001.jpeg', 'NORMAL2-IM-0460-0001.jpeg', 'IM-0424-0001.jpeg', 'IM-0176-0001.jpeg', 'NORMAL2-IM-0832-0001.jpeg', 'NORMAL2-IM-1288-0001.jpeg', 'NORMAL2-IM-0918-0001.jpeg', 'IM-0523-0001-0001.jpeg', 'NORMAL2-IM-1152-0001-0001.jpeg', 'NORMAL2-IM-0705-0001.jpeg', 'NORMAL2-IM-0893-0001.jpeg', 'NORMAL2-IM-0643-0001.jpeg', 'NORMAL2-IM-0539-0001.jpeg', 'IM-0122-0001.jpeg', 'IM-0557-0001.jpeg', 'NORMAL2-IM-0641-0001.jpeg', 'NORMAL2-IM-1262-0001.jpeg', 'NORMAL2-IM-0609-0001.jpeg', 'IM-0681-0001.jpeg', 'NORMAL2-IM-1220-0001.jpeg', 'NORMAL2-IM-1154-0001-0002.jpeg', 'NORMAL2-IM-0667-0001.jpeg', 'IM-0712-0001.jpeg', 'NORMAL2-IM-1161-0001.jpeg', 'IM-0491-0001-0001.jpeg', 'NORMAL2-IM-0448-0001.jpeg', 'IM-0464-0001.jpeg', 'NORMAL2-IM-1351-0001.jpeg', 'IM-0637-0001.jpeg', 'IM-0696-0001.jpeg', 'NORMAL2-IM-1110-0001.jpeg', 'NORMAL2-IM-1285-0001.jpeg', 'NORMAL2-IM-1281-0001.jpeg', 'NORMAL2-IM-1049-0001.jpeg', 'NORMAL2-IM-1096-0001-0001.jpeg', 'NORMAL2-IM-1177-0001.jpeg', 'NORMAL2-IM-0970-0001.jpeg', 'NORMAL2-IM-1257-0001.jpeg', 'NORMAL2-IM-1269-0001-0002.jpeg', 'IM-0612-0001.jpeg', 'IM-0479-0001.jpeg', 'IM-0626-0001-0002.jpeg', 'IM-0511-0001.jpeg', 'IM-0549-0001-0001.jpeg', 'IM-0686-0001.jpeg', 'IM-0473-0001.jpeg', 'IM-0421-0001.jpeg', 'NORMAL2-IM-0502-0001.jpeg', 'IM-0256-0001.jpeg', 'NORMAL2-IM-1123-0001.jpeg', 'NORMAL2-IM-1376-0001.jpeg', 'IM-0456-0001.jpeg', 'NORMAL2-IM-0978-0001.jpeg', 'NORMAL2-IM-0587-0001-0001.jpeg', 'NORMAL2-IM-0959-0001.jpeg', 'NORMAL2-IM-1270-0001.jpeg', 'IM-0193-0001.jpeg', 'IM-0705-0001.jpeg', 'IM-0158-0001.jpeg', 'NORMAL2-IM-1113-0001.jpeg', 'IM-0437-0001-0001.jpeg', 'NORMAL2-IM-0456-0001.jpeg', 'NORMAL2-IM-1142-0001-0001.jpeg', 'IM-0519-0001.jpeg', 'IM-0308-0001.jpeg', 'NORMAL2-IM-1102-0001-0001.jpeg', 'IM-0663-0001.jpeg', 'NORMAL2-IM-0672-0001.jpeg', 'NORMAL2-IM-0976-0001.jpeg', 'NORMAL2-IM-0749-0001.jpeg', 'IM-0475-0001.jpeg', 'NORMAL2-IM-0979-0001.jpeg', 'IM-0747-0001.jpeg', 'IM-0640-0001.jpeg', 'NORMAL2-IM-0661-0001.jpeg', 'IM-0299-0001.jpeg', 'NORMAL2-IM-0450-0001.jpeg', 'IM-0403-0001.jpeg', 'NORMAL2-IM-0649-0001.jpeg', 'NORMAL2-IM-1345-0001.jpeg', 'IM-0583-0001.jpeg', 'NORMAL2-IM-1231-0001.jpeg', 'NORMAL2-IM-0869-0001.jpeg', 'NORMAL2-IM-0437-0001.jpeg', 'NORMAL2-IM-0983-0001-0002.jpeg', 'NORMAL2-IM-1181-0001.jpeg', 'NORMAL2-IM-1362-0001.jpeg', 'IM-0449-0001.jpeg', 'IM-0395-0001.jpeg', 'IM-0644-0001.jpeg', 'NORMAL2-IM-0503-0001.jpeg', 'IM-0356-0001.jpeg', 'NORMAL2-IM-1200-0001.jpeg', 'IM-0680-0001.jpeg', 'NORMAL2-IM-0555-0001-0002.jpeg', 'NORMAL2-IM-0790-0001.jpeg', 'NORMAL2-IM-0577-0001.jpeg', 'NORMAL2-IM-1218-0001.jpeg', 'IM-0665-0001.jpeg', 'IM-0467-0001-0002.jpeg', 'NORMAL2-IM-1128-0001.jpeg', 'IM-0507-0001.jpeg', 'NORMAL2-IM-1267-0001.jpeg', 'NORMAL2-IM-0931-0001.jpeg', 'NORMAL2-IM-0744-0001.jpeg', 'IM-0612-0001-0002.jpeg', 'NORMAL2-IM-0399-0001.jpeg', 'NORMAL2-IM-1247-0001.jpeg', 'IM-0729-0001.jpeg', 'IM-0608-0001-0001.jpeg', 'NORMAL2-IM-1275-0001.jpeg', 'NORMAL2-IM- ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/chest_xray/train/PNEUMONIA
# Subdirectories: []
# Files: ['person1551_virus_2692.jpeg', 'person547_bacteria_2294.jpeg', 'person334_virus_689.jpeg', 'person1199_bacteria_3149.jpeg', 'person383_bacteria_1754.jpeg', 'person30_bacteria_151.jpeg', 'person1105_bacteria_3046.jpeg', 'person992_bacteria_2920.jpeg', 'person1465_virus_2537.jpeg', 'person138_virus_282.jpeg', 'person741_virus_1364.jpeg', 'person25_bacteria_121.jpeg', 'person1657_bacteria_4398.jpeg', 'person571_bacteria_2367.jpeg', 'person299_bacteria_1419.jpeg', 'person39_bacteria_200.jpeg', 'person88_virus_163.jpeg', 'person1223_bacteria_3178.jpeg', 'person1216_bacteria_3168.jpeg', 'person402_bacteria_1813.jpeg', 'person596_bacteria_2440.jpeg', 'person988_bacteria_2915.jpeg', 'person483_virus_985.jpeg', 'person1095_virus_1815.jpeg', 'person1481_bacteria_3867.jpeg', 'person61_bacteria_292.jpeg', 'person1927_bacteria_4837.jpeg', 'person492_virus_998.jpeg', 'person1133_virus_1865.jpeg', 'person31_bacteria_162.jpeg', 'person1507_bacteria_3943.jpeg', 'person338_bacteria_1568.jpeg', 'person1186_bacteria_3134.jpeg', 'person1216_virus_2062.jpeg', 'person315_bacteria_1467.jpeg', 'person61_bacteria_296.jpeg', 'person368_bacteria_1668.jpeg', 'person408_virus_815.jpeg', 'person275_virus_565.jpeg', 'person445_virus_919.jpeg', 'person1462_virus_2512.jpeg', 'person545_bacteria_2289.jpeg', 'person1718_bacteria_4538.jpeg', 'person1702_bacteria_4510.jpeg', 'person625_bacteria_2500.jpeg', 'person1670_bacteria_4425.jpeg', 'person1493_bacteria_3899.jpeg', 'person1415_virus_2425.jpeg', 'person256_bacteria_1189.jpeg', 'person775_bacteria_2679.jpeg', 'person761_virus_1389.jpeg', 'person995_bacteria_2923.jpeg', 'person547_bacteria_2296.jpeg', 'person534_virus_1061.jpeg', 'person541_bacteria_2275.jpeg', 'person1426_bacteria_3667.jpeg', 'person1880_bacteria_4765.jpeg', 'person420_bacteria_1848.jpeg', 'person1884_bacteria_4771.jpeg', 'person1256_bacteria_3214.jpeg', 'person1395_virus_2398.jpeg', 'person1438_bacteria_3715.jpeg', 'person1333_bacteria_3384.jpeg', 'person749_virus_1374.jpeg', 'person486_bacteria_2052.jpeg', 'person1872_bacteria_4751.jpeg', 'person5_bacteria_15.jpeg', 'person1052_virus_1751.jpeg', 'person363_virus_742.jpeg', 'person1451_virus_2482.jpeg', 'person1454_bacteria_3780.jpeg', 'person1164_virus_1958.jpeg', 'person1321_bacteria_3358.jpeg', 'person417_bacteria_1841.jpeg', 'person1814_bacteria_4669.jpeg', 'person299_virus_620.jpeg', 'person466_bacteria_1986.jpeg', 'person1445_bacteria_3734.jpeg', 'person491_bacteria_2081.jpeg', 'person124_virus_247.jpeg', 'person534_bacteria_2254.jpeg', 'person1186_virus_2022.jpeg', 'person617_bacteria_2488.jpeg', 'person834_bacteria_2748.jpeg', 'person1433_bacteria_3704.jpeg', 'person24_bacteria_112.jpeg', 'person142_virus_288.jpeg', 'person26_bacteria_133.jpeg', 'person1168_virus_1966.jpeg', 'person1628_bacteria_4295.jpeg', 'person1098_virus_1818.jpeg', 'person952_virus_1623.jpeg', 'person476_bacteria_2026.jpeg', 'person1361_bacteria_3476.jpeg', 'person462_bacteria_1961.jpeg', 'person548_bacteria_2300.jpeg', 'person1312_bacteria_3319.jpeg', 'person795_virus_1427.jpeg', 'person299_bacteria_1416.jpeg', 'person257_bacteria_1196.jpeg', 'person705_virus_1302.jpeg', 'person637_bacteria_2528.jpeg', 'person1067_bacteria_3001.jpeg', 'person508_virus_1020.jpeg', 'person529_virus_1050.jpeg', 'person1491_bacteria_3893.jpeg', 'person543_bacteria_2280.jpeg', 'person873_bacteria_2796.jpeg', 'person500_bacteria_2109.jpeg', 'person1288_virus_2211.jpeg', 'person1233_bacteria_3188.jpeg', 'person493_bacteria_2086.jpeg', 'person647_virus_1228.jpeg', 'person409_virus_820.jpeg', 'person1885_bacteria_4772.jpeg', 'person1609_virus_2790.jpeg', 'person449_bacteria_1940.jpeg', 'person1602_virus_2780.jpeg', 'person1407_virus_2410.jpeg', 'person1049_bacteria_2983.jpeg', 'person38_bacteria_193.jpeg', 'person1307_bacteria_3278.jpeg', 'person1470_bacteria_3830.jpeg', 'person1180_virus_2014.jpeg', 'person373_bacteria_1708.jpeg', 'person1011_bacteria_2942.jpeg', 'person437_bacteria_1887.jpeg', 'person443_bacteria_1924.jpeg', 'pe ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/val
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: []
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/val/NORMAL
# Subdirectories: []
# Files: ['NORMAL2-IM-1431-0001.jpeg', 'NORMAL2-IM-1440-0001.jpeg', 'NORMAL2-IM-1427-0001.jpeg', 'NORMAL2-IM-1436-0001.jpeg', 'NORMAL2-IM-1437-0001.jpeg', 'NORMAL2-IM-1430-0001.jpeg', 'NORMAL2-IM-1442-0001.jpeg', 'NORMAL2-IM-1438-0001.jpeg']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/val/PNEUMONIA
# Subdirectories: []
# Files: ['person1947_bacteria_4876.jpeg', 'person1946_bacteria_4875.jpeg', 'person1951_bacteria_4882.jpeg', 'person1946_bacteria_4874.jpeg', 'person1952_bacteria_4883.jpeg', 'person1949_bacteria_4880.jpeg', 'person1950_bacteria_4881.jpeg', 'person1954_bacteria_4886.jpeg']
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/train
# Subdirectories: ['NORMAL', 'PNEUMONIA']
# Files: []
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/train/NORMAL
# Subdirectories: []
# Files: ['IM-0417-0001.jpeg', 'NORMAL2-IM-1301-0001.jpeg', 'IM-0375-0001.jpeg', 'NORMAL2-IM-1314-0001.jpeg', 'IM-0286-0001.jpeg', 'NORMAL2-IM-0671-0001.jpeg', 'NORMAL2-IM-0957-0001.jpeg', 'IM-0137-0001.jpeg', 'NORMAL2-IM-1054-0001.jpeg', 'IM-0717-0001.jpeg', 'NORMAL2-IM-0416-0001-0001.jpeg', 'NORMAL2-IM-0904-0001.jpeg', 'IM-0300-0001.jpeg', 'IM-0622-0001-0002.jpeg', 'IM-0549-0001.jpeg', 'IM-0474-0001.jpeg', 'NORMAL2-IM-0652-0001.jpeg', 'IM-0302-0001.jpeg', 'NORMAL2-IM-0601-0001.jpeg', 'IM-0477-0001.jpeg', 'NORMAL2-IM-1345-0001-0001.jpeg', 'NORMAL2-IM-0425-0001.jpeg', 'IM-0604-0001.jpeg', 'NORMAL2-IM-1136-0001.jpeg', 'NORMAL2-IM-0618-0001.jpeg', 'NORMAL2-IM-0960-0001.jpeg', 'NORMAL2-IM-0480-0001.jpeg', 'NORMAL2-IM-0573-0001.jpeg', 'IM-0666-0001-0001.jpeg', 'NORMAL2-IM-1260-0001.jpeg', 'IM-0236-0001.jpeg', 'IM-0579-0001.jpeg', 'NORMAL2-IM-0803-0001.jpeg', 'NORMAL2-IM-0999-0001.jpeg', 'NORMAL2-IM-0552-0001.jpeg', 'IM-0670-0001.jpeg', 'IM-0346-0001.jpeg', 'NORMAL2-IM-1209-0001.jpeg', 'IM-0493-0001.jpeg', 'NORMAL2-IM-0741-0001.jpeg', 'NORMAL2-IM-1108-0001.jpeg', 'NORMAL2-IM-0460-0001.jpeg', 'IM-0424-0001.jpeg', 'IM-0176-0001.jpeg', 'NORMAL2-IM-0832-0001.jpeg', 'NORMAL2-IM-1288-0001.jpeg', 'NORMAL2-IM-0918-0001.jpeg', 'IM-0523-0001-0001.jpeg', 'NORMAL2-IM-1152-0001-0001.jpeg', 'NORMAL2-IM-0705-0001.jpeg', 'NORMAL2-IM-0893-0001.jpeg', 'NORMAL2-IM-0643-0001.jpeg', 'NORMAL2-IM-0539-0001.jpeg', 'IM-0122-0001.jpeg', 'IM-0557-0001.jpeg', 'NORMAL2-IM-0641-0001.jpeg', 'NORMAL2-IM-1262-0001.jpeg', 'NORMAL2-IM-0609-0001.jpeg', 'IM-0681-0001.jpeg', 'NORMAL2-IM-1220-0001.jpeg', 'NORMAL2-IM-1154-0001-0002.jpeg', 'NORMAL2-IM-0667-0001.jpeg', 'IM-0712-0001.jpeg', 'NORMAL2-IM-1161-0001.jpeg', 'IM-0491-0001-0001.jpeg', 'NORMAL2-IM-0448-0001.jpeg', 'IM-0464-0001.jpeg', 'NORMAL2-IM-1351-0001.jpeg', 'IM-0637-0001.jpeg', 'IM-0696-0001.jpeg', 'NORMAL2-IM-1110-0001.jpeg', 'NORMAL2-IM-1285-0001.jpeg', 'NORMAL2-IM-1281-0001.jpeg', 'NORMAL2-IM-1049-0001.jpeg', 'NORMAL2-IM-1096-0001-0001.jpeg', 'NORMAL2-IM-1177-0001.jpeg', 'NORMAL2-IM-0970-0001.jpeg', 'NORMAL2-IM-1257-0001.jpeg', 'NORMAL2-IM-1269-0001-0002.jpeg', 'IM-0612-0001.jpeg', 'IM-0479-0001.jpeg', 'IM-0626-0001-0002.jpeg', 'IM-0511-0001.jpeg', 'IM-0549-0001-0001.jpeg', 'IM-0686-0001.jpeg', 'IM-0473-0001.jpeg', 'IM-0421-0001.jpeg', 'NORMAL2-IM-0502-0001.jpeg', 'IM-0256-0001.jpeg', 'NORMAL2-IM-1123-0001.jpeg', 'NORMAL2-IM-1376-0001.jpeg', 'IM-0456-0001.jpeg', 'NORMAL2-IM-0978-0001.jpeg', 'NORMAL2-IM-0587-0001-0001.jpeg', 'NORMAL2-IM-0959-0001.jpeg', 'NORMAL2-IM-1270-0001.jpeg', 'IM-0193-0001.jpeg', 'IM-0705-0001.jpeg', 'IM-0158-0001.jpeg', 'NORMAL2-IM-1113-0001.jpeg', 'IM-0437-0001-0001.jpeg', 'NORMAL2-IM-0456-0001.jpeg', 'NORMAL2-IM-1142-0001-0001.jpeg', 'IM-0519-0001.jpeg', 'IM-0308-0001.jpeg', 'NORMAL2-IM-1102-0001-0001.jpeg', 'IM-0663-0001.jpeg', 'NORMAL2-IM-0672-0001.jpeg', 'NORMAL2-IM-0976-0001.jpeg', 'NORMAL2-IM-0749-0001.jpeg', 'IM-0475-0001.jpeg', 'NORMAL2-IM-0979-0001.jpeg', 'IM-0747-0001.jpeg', 'IM-0640-0001.jpeg', 'NORMAL2-IM-0661-0001.jpeg', 'IM-0299-0001.jpeg', 'NORMAL2-IM-0450-0001.jpeg', 'IM-0403-0001.jpeg', 'NORMAL2-IM-0649-0001.jpeg', 'NORMAL2-IM-1345-0001.jpeg', 'IM-0583-0001.jpeg', 'NORMAL2-IM-1231-0001.jpeg', 'NORMAL2-IM-0869-0001.jpeg', 'NORMAL2-IM-0437-0001.jpeg', 'NORMAL2-IM-0983-0001-0002.jpeg', 'NORMAL2-IM-1181-0001.jpeg', 'NORMAL2-IM-1362-0001.jpeg', 'IM-0449-0001.jpeg', 'IM-0395-0001.jpeg', 'IM-0644-0001.jpeg', 'NORMAL2-IM-0503-0001.jpeg', 'IM-0356-0001.jpeg', 'NORMAL2-IM-1200-0001.jpeg', 'IM-0680-0001.jpeg', 'NORMAL2-IM-0555-0001-0002.jpeg', 'NORMAL2-IM-0790-0001.jpeg', 'NORMAL2-IM-0577-0001.jpeg', 'NORMAL2-IM-1218-0001.jpeg', 'IM-0665-0001.jpeg', 'IM-0467-0001-0002.jpeg', 'NORMAL2-IM-1128-0001.jpeg', 'IM-0507-0001.jpeg', 'NORMAL2-IM-1267-0001.jpeg', 'NORMAL2-IM-0931-0001.jpeg', 'NORMAL2-IM-0744-0001.jpeg', 'IM-0612-0001-0002.jpeg', 'NORMAL2-IM-0399-0001.jpeg', 'NORMAL2-IM-1247-0001.jpeg', 'IM-0729-0001.jpeg', 'IM-0608-0001-0001.jpeg', 'NORMAL2-IM-1275-0001.jpeg', 'NORMAL2-IM- ...
# ----------------------------------------
# Directory: /root/.cache/kagglehub/datasets/paultimothymooney/chest-xray-pneumonia/versions/2/chest_xray/train/PNEUMONIA
# Subdirectories: []
# Files: ['person1551_virus_2692.jpeg', 'person547_bacteria_2294.jpeg', 'person334_virus_689.jpeg', 'person1199_bacteria_3149.jpeg', 'person383_bacteria_1754.jpeg', 'person30_bacteria_151.jpeg', 'person1105_bacteria_3046.jpeg', 'person992_bacteria_2920.jpeg', 'person1465_virus_2537.jpeg', 'person138_virus_282.jpeg', 'person741_virus_1364.jpeg', 'person25_bacteria_121.jpeg', 'person1657_bacteria_4398.jpeg', 'person571_bacteria_2367.jpeg', 'person299_bacteria_1419.jpeg', 'person39_bacteria_200.jpeg', 'person88_virus_163.jpeg', 'person1223_bacteria_3178.jpeg', 'person1216_bacteria_3168.jpeg', 'person402_bacteria_1813.jpeg', 'person596_bacteria_2440.jpeg', 'person988_bacteria_2915.jpeg', 'person483_virus_985.jpeg', 'person1095_virus_1815.jpeg', 'person1481_bacteria_3867.jpeg', 'person61_bacteria_292.jpeg', 'person1927_bacteria_4837.jpeg', 'person492_virus_998.jpeg', 'person1133_virus_1865.jpeg', 'person31_bacteria_162.jpeg', 'person1507_bacteria_3943.jpeg', 'person338_bacteria_1568.jpeg', 'person1186_bacteria_3134.jpeg', 'person1216_virus_2062.jpeg', 'person315_bacteria_1467.jpeg', 'person61_bacteria_296.jpeg', 'person368_bacteria_1668.jpeg', 'person408_virus_815.jpeg', 'person275_virus_565.jpeg', 'person445_virus_919.jpeg', 'person1462_virus_2512.jpeg', 'person545_bacteria_2289.jpeg', 'person1718_bacteria_4538.jpeg', 'person1702_bacteria_4510.jpeg', 'person625_bacteria_2500.jpeg', 'person1670_bacteria_4425.jpeg', 'person1493_bacteria_3899.jpeg', 'person1415_virus_2425.jpeg', 'person256_bacteria_1189.jpeg', 'person775_bacteria_2679.jpeg', 'person761_virus_1389.jpeg', 'person995_bacteria_2923.jpeg', 'person547_bacteria_2296.jpeg', 'person534_virus_1061.jpeg', 'person541_bacteria_2275.jpeg', 'person1426_bacteria_3667.jpeg', 'person1880_bacteria_4765.jpeg', 'person420_bacteria_1848.jpeg', 'person1884_bacteria_4771.jpeg', 'person1256_bacteria_3214.jpeg', 'person1395_virus_2398.jpeg', 'person1438_bacteria_3715.jpeg', 'person1333_bacteria_3384.jpeg', 'person749_virus_1374.jpeg', 'person486_bacteria_2052.jpeg', 'person1872_bacteria_4751.jpeg', 'person5_bacteria_15.jpeg', 'person1052_virus_1751.jpeg', 'person363_virus_742.jpeg', 'person1451_virus_2482.jpeg', 'person1454_bacteria_3780.jpeg', 'person1164_virus_1958.jpeg', 'person1321_bacteria_3358.jpeg', 'person417_bacteria_1841.jpeg', 'person1814_bacteria_4669.jpeg', 'person299_virus_620.jpeg', 'person466_bacteria_1986.jpeg', 'person1445_bacteria_3734.jpeg', 'person491_bacteria_2081.jpeg', 'person124_virus_247.jpeg', 'person534_bacteria_2254.jpeg', 'person1186_virus_2022.jpeg', 'person617_bacteria_2488.jpeg', 'person834_bacteria_2748.jpeg', 'person1433_bacteria_3704.jpeg', 'person24_bacteria_112.jpeg', 'person142_virus_288.jpeg', 'person26_bacteria_133.jpeg', 'person1168_virus_1966.jpeg', 'person1628_bacteria_4295.jpeg', 'person1098_virus_1818.jpeg', 'person952_virus_1623.jpeg', 'person476_bacteria_2026.jpeg', 'person1361_bacteria_3476.jpeg', 'person462_bacteria_1961.jpeg', 'person548_bacteria_2300.jpeg', 'person1312_bacteria_3319.jpeg', 'person795_virus_1427.jpeg', 'person299_bacteria_1416.jpeg', 'person257_bacteria_1196.jpeg', 'person705_virus_1302.jpeg', 'person637_bacteria_2528.jpeg', 'person1067_bacteria_3001.jpeg', 'person508_virus_1020.jpeg', 'person529_virus_1050.jpeg', 'person1491_bacteria_3893.jpeg', 'person543_bacteria_2280.jpeg', 'person873_bacteria_2796.jpeg', 'person500_bacteria_2109.jpeg', 'person1288_virus_2211.jpeg', 'person1233_bacteria_3188.jpeg', 'person493_bacteria_2086.jpeg', 'person647_virus_1228.jpeg', 'person409_virus_820.jpeg', 'person1885_bacteria_4772.jpeg', 'person1609_virus_2790.jpeg', 'person449_bacteria_1940.jpeg', 'person1602_virus_2780.jpeg', 'person1407_virus_2410.jpeg', 'person1049_bacteria_2983.jpeg', 'person38_bacteria_193.jpeg', 'person1307_bacteria_3278.jpeg', 'person1470_bacteria_3830.jpeg', 'person1180_virus_2014.jpeg', 'person373_bacteria_1708.jpeg', 'person1011_bacteria_2942.jpeg', 'person437_bacteria_1887.jpeg', 'person443_bacteria_1924.jpeg', 'pe ...
# ----------------------------------------

# %% [markdown]
# #  2. Partition Images of Training and Test Data to Seperate Pandas Dataframes

# %%
# Prepare training data
def prepare_dataset(data_dir):
    filepaths, labels = [], []
    for category in os.listdir(data_dir):
        category_path = os.path.join(data_dir, category)
        for img_file in os.listdir(category_path):
            filepaths.append(os.path.join(category_path, img_file))
            labels.append(category)
    return pd.DataFrame({'filepath': filepaths, 'label': labels})

train_dir = os.path.join(dataset_path, "chest_xray/train")
test_dir = os.path.join(dataset_path, "chest_xray/test")

df_train = prepare_dataset(train_dir)
df_test = prepare_dataset(test_dir)

# %%
# Visualize label distribution
def plot_label_distribution(df, title):
    label_counts = df['label'].value_counts()
    fig, axs = plt.subplots(1, 2, figsize=(10, 4), facecolor='white')
    palette = sns.color_palette("coolwarm")

    # Pie chart
    axs[0].pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=140, colors=palette)
    axs[0].set_title(f'{title} - Pie Chart')

    # Bar chart
    sns.barplot(x=label_counts.index, y=label_counts.values, ax=axs[1], palette=palette)
    axs[1].set_title(f'{title} - Bar Chart')
    axs[1].set_xlabel('Categories')
    axs[1].set_ylabel('Counts')

    plt.tight_layout()
    plt.show()

plot_label_distribution(df_train, "Training Data")
plot_label_distribution(df_test, "Testing Data")

# %% [markdown]
# # 3. Preprocessing

# %%
#Preprocessing V2 - With Data augmentation techniques

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image dimensions and batch size
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 32

# Create data augmentation object
datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,  # Normalize pixel values
    rotation_range=20,    # Rotate images randomly within 20 degrees
    width_shift_range=0.1,  # Shift horizontally by 10%
    height_shift_range=0.1,  # Shift vertically by 10%
    shear_range=0.1,       # Apply shearing
    zoom_range=0.2,        # Random zoom
    horizontal_flip=True,  # Flip horizontally
    validation_split=0.1   # Reserve 10% of training data for validation
)

# Load augmented training data
train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',  # Use binary mode for binary classification
    subset='training',    # Training subset
    seed=123              # Ensure reproducibility
)

# Load validation data (no augmentation, just rescaling)
val_datagen = ImageDataGenerator(rescale=1.0 / 255.0, validation_split=0.1)
val_generator = val_datagen.flow_from_directory(
    train_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation',
    seed=123
)

# Test dataset (no augmentation, just rescaling)
test_datagen = ImageDataGenerator(rescale=1.0 / 255.0)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False  # Do not shuffle for consistent evaluation
)
# Out:
# Found 4695 images belonging to 2 classes.
# Found 521 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
"""
# Image dimensions and batch size
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 32

# Create datasets
train_dataset = image_dataset_from_directory(
    train_dir, validation_split=0.1, subset="training", seed=123,
    image_size=IMAGE_SIZE, batch_size=BATCH_SIZE
)
val_dataset = image_dataset_from_directory(
    train_dir, validation_split=0.1, subset="validation", seed=123,
    image_size=IMAGE_SIZE, batch_size=BATCH_SIZE
)
test_dataset = image_dataset_from_directory(
    test_dir, seed=123, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE
)

# Normalize pixel values
def normalize_dataset(ds):
    return ds.map(lambda x, y: (x / 255.0, y))

train_dataset = normalize_dataset(train_dataset)
val_dataset = normalize_dataset(val_dataset)
test_dataset = normalize_dataset(test_dataset)
"""
# Out:
# '\n# Image dimensions and batch size\nIMAGE_SIZE = (256, 256)\nBATCH_SIZE = 32\n\n# Create datasets\ntrain_dataset = image_dataset_from_directory(\n    train_dir, validation_split=0.1, subset="training", seed=123,\n    image_size=IMAGE_SIZE, batch_size=BATCH_SIZE\n)\nval_dataset = image_dataset_from_directory(\n    train_dir, validation_split=0.1, subset="validation", seed=123,\n    image_size=IMAGE_SIZE, batch_size=BATCH_SIZE\n)\ntest_dataset = image_dataset_from_directory(\n    test_dir, seed=123, image_size=IMAGE_SIZE, batch_size=BATCH_SIZE\n)\n\n# Normalize pixel values\ndef normalize_dataset(ds):\n    return ds.map(lambda x, y: (x / 255.0, y))\n\ntrain_dataset = normalize_dataset(train_dataset)\nval_dataset = normalize_dataset(val_dataset)\ntest_dataset = normalize_dataset(test_dataset)\n'

# %% [markdown]
# # 4. Vizualization of Examples from Training Directory

# %%
# Visualize images from a given directory
def visualize_sample_images(data_dir, title, num_images=5):
    image_paths = os.listdir(data_dir)[:num_images]
    fig, axes = plt.subplots(1, num_images, figsize=(15, 3), facecolor='white')
    for i, img_file in enumerate(image_paths):
        img = plt.imread(os.path.join(data_dir, img_file))
        axes[i].imshow(img)
        axes[i].axis('off')
        axes[i].set_title(img_file[:10])  # Show partial filename
    fig.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

visualize_sample_images(os.path.join(train_dir, "NORMAL"), "Sample Normal Images (from dir, not augmented training data)")
visualize_sample_images(os.path.join(train_dir, "PNEUMONIA"), "Sample Pneumonia Images (from dir, not augmented training data)")

# %%
# Plot training accuracy and loss
def plot_training_history(history):
    fig, axs = plt.subplots(1, 2, figsize=(14, 6), facecolor='white')

    # Accuracy plot
    axs[0].plot(history.history['accuracy'], label='Train Accuracy', color='blue')
    axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')
    axs[0].set_title('Accuracy over Epochs')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    # Loss plot
    axs[1].plot(history.history['loss'], label='Train Loss', color='blue')
    axs[1].plot(history.history['val_loss'], label='Validation Loss', color='orange')
    axs[1].set_title('Loss over Epochs')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## ResNet50 Model

# %%
# Unfreeze the last few layers of ResNet50
def fine_tune_resnet50_model(model, num_layers_to_unfreeze):
    base_model = model.layers[0]  # Extract the pre-trained ResNet50 base model
    for layer in base_model.layers[-num_layers_to_unfreeze:]:
        layer.trainable = True  # Unfreeze these layers

    # Compile the model again with a lower learning rate
    model.compile(optimizer=Adam(learning_rate=0.0001),  # Fine-tuning requires a smaller learning rate
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
def build_model(input_shape):
    base_model = ResNet50(input_shape=input_shape, include_top=False, weights="imagenet")

    base_model.trainable = False  # Unfreeze the base model (deeper layers to adapt these specific features to the pneumonia dataset)

    model = Sequential([
        base_model,
        Flatten(),
        Dense(128, activation='relu'),
        Dense(1, activation='sigmoid')  # Binary classification
    ])
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='binary_crossentropy', metrics=['accuracy'])
    return model

model = build_model((*IMAGE_SIZE, 3))

# Early stopping callback
early_stopping = EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)

# Train model
history = model.fit(
    train_generator, validation_data=val_generator, epochs=10, callbacks=[early_stopping]
)
model.summary()
plot_training_history(history)
# Out:
# Epoch 1/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 137s 810ms/step - accuracy: 0.6867 - loss: 3.6915 - val_accuracy: 0.8868 - val_loss: 0.3733
# Epoch 2/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 123s 724ms/step - accuracy: 0.8138 - loss: 0.6831 - val_accuracy: 0.6219 - val_loss: 1.3132
# Epoch 3/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 112s 733ms/step - accuracy: 0.8255 - loss: 0.6009 - val_accuracy: 0.8887 - val_loss: 0.3842
# Epoch 4/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 117s 758ms/step - accuracy: 0.8462 - loss: 0.5759 - val_accuracy: 0.8484 - val_loss: 0.5892
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 8, 8, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 131072)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      16,777,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 73,920,133 (281.98 MB)
#  Trainable params: 16,777,473 (64.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)
#  Optimizer params: 33,554,948 (128.00 MB)

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 473ms/step - accuracy: 0.7600 - loss: 0.6525
# Test Accuracy: 0.84

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

# Generate predictions
y_pred = model.predict(test_generator)
y_pred_classes = (y_pred > 0.5).astype(int).flatten()  # Convert probabilities to binary classes
y_true = test_generator.classes  # True labels from the generator

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred_classes, labels=[0, 1])

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_generator.class_indices.keys())
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 12s 410ms/step

# %%
#Finetuned model

model = fine_tune_resnet50_model(model, num_layers_to_unfreeze=10)

# Early stopping callback
early_stopping = EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)

# Train model
history = model.fit(
    train_generator, validation_data=val_generator, epochs=10, callbacks=[early_stopping]
)
model.summary()
plot_training_history(history)
# Out:
# Epoch 1/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 134s 803ms/step - accuracy: 0.8642 - loss: 0.4570 - val_accuracy: 0.8560 - val_loss: 0.2866
# Epoch 2/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 128s 739ms/step - accuracy: 0.8911 - loss: 0.2654 - val_accuracy: 0.9386 - val_loss: 0.1631
# Epoch 3/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 112s 734ms/step - accuracy: 0.9062 - loss: 0.2387 - val_accuracy: 0.7524 - val_loss: 0.7742
# Epoch 4/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 141s 728ms/step - accuracy: 0.8915 - loss: 0.2790 - val_accuracy: 0.9347 - val_loss: 0.1717
# Epoch 5/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 115s 750ms/step - accuracy: 0.9202 - loss: 0.2033 - val_accuracy: 0.7428 - val_loss: 1.0774
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 8, 8, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 131072)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │      16,777,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 82,851,461 (316.05 MB)
#  Trainable params: 21,243,137 (81.04 MB)
#  Non-trainable params: 19,122,048 (72.94 MB)
#  Optimizer params: 42,486,276 (162.07 MB)

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 327ms/step - accuracy: 0.6973 - loss: 0.7899
# Test Accuracy: 0.82

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

# Generate predictions
y_pred = model.predict(test_generator)
y_pred_classes = (y_pred > 0.5).astype(int).flatten()  # Convert probabilities to binary classes
y_true = test_generator.classes  # True labels from the generator

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred_classes, labels=[0, 1])

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_generator.class_indices.keys())
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 11s 393ms/step

# %% [markdown]
# # Custom CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

def build_custom_cnn(input_shape):
    model = Sequential()

    # Block 1
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))  # Extract features with 32 filters
    model.add(BatchNormalization())  # Normalize activations for faster convergence
    model.add(MaxPooling2D(pool_size=(2, 2)))  # Downsample spatial dimensions
    model.add(Dropout(0.25))  # Mitigate overfitting

    # Block 2
    model.add(Conv2D(64, (3, 3), activation='relu'))  # Extract deeper features with 64 filters
    model.add(BatchNormalization())  # Normalize activations for stability
    model.add(MaxPooling2D(pool_size=(2, 2)))  # Reduce spatial dimensions
    model.add(Dropout(0.25))  # Prevent overfitting

    # Block 3
    model.add(Conv2D(128, (3, 3), activation='relu'))  # Extract higher-level features with 128 filters
    model.add(BatchNormalization())  # Normalize activations
    model.add(MaxPooling2D(pool_size=(2, 2)))  # Further reduce spatial dimensions
    model.add(Dropout(0.25))  # Mitigate overfitting

    # Fully Connected Layers
    model.add(Flatten())  # Flatten feature maps for dense layers
    model.add(Dense(128, activation='relu'))  # Dense layer with ReLU activation
    model.add(Dropout(0.5))  # Reduce overfitting
    model.add(Dense(1, activation='sigmoid'))  # Activation function for binary classification

    # Compile the model
    model.compile(
        optimizer='adam',  # Adaptive learning rate optimization
        loss='binary_crossentropy',  # Loss for binary classification
        metrics=['accuracy']  # Track accuracy during training
    )
    return model

# %%
# Define the input shape (e.g., (256, 256, 3) for RGB images of size 256x256)
input_shape = (*IMAGE_SIZE, 3)

# Build the model
custom_cnn_model = build_custom_cnn(input_shape)

# Train the model
history = custom_cnn_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,
    callbacks=[early_stopping]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-778b179bd0a8> in <cell line: 1>()
# ----> 1 history = custom_cnn_model.fit(
#       2     train_generator,
#       3     validation_data=val_generator,
#       4     epochs=10,
#       5     callbacks=[early_stopping]
#
# NameError: name 'custom_cnn_model' is not defined

# %%
test_loss, test_accuracy = custom_cnn_model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy:.2f}")

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

# Generate predictions
y_pred = custom_cnn_model.predict(test_generator)
y_pred_classes = (y_pred > 0.5).astype(int).flatten()  # Convert probabilities to binary classes
y_true = test_generator.classes  # True labels from the generator

# Create confusion matrix
cm = confusion_matrix(y_true, y_pred_classes, labels=[0, 1])

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_generator.class_indices.keys())
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
# creating histogram
plt.figure(figsize=(8, 6))
sns.histplot(y_pred_proba[y_true == 0], bins=20, color='red', label='Normal', kde=True)
sns.histplot(y_pred_proba[y_true == 1], bins=20, color='blue', label='Pneumonia', kde=True)
plt.title('Prediction Probability Distribution')
plt.xlabel('Predicted Probability')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

# Generate a classification report
class_report = classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys())
print("Classification Report:\n")
print(class_report)

# %%
from sklearn.metrics import roc_curve, auc

# Generate probabilities
y_pred_proba = y_pred.flatten()  # Probabilities from the model

# Compute ROC curve and AUC
fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f"ROC Curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()
